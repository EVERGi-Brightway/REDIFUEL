# %%
import premise
premise.__version__
# Out:
# (1, 1, 5)

# %%
from premise import *
import brightway2 as bw

# %%
bw.projects.set_current("Prospective LCA")

# %%
ndb = NewDatabase(
            scenarios=[
                {"model":"IMAGE", "pathway":"SSP2-Base", "year":2030},
                {"model":"IMAGE", "pathway":"SSP2-Base", "year":2050},
                {"model":"IMAGE", "pathway":"SSP2-RCP19", "year":2030},
                {"model":"IMAGE", "pathway":"SSP2-RCP19", "year":2050},
            ],
            source_db="cutoff38", # <-- name of the database in the BW2 project. Must be a string.
            source_version="3.8", # <-- version of ecoinvent. Can be "3.5", "3.6", "3.7" or "3.7.1". Must be a string.
            key='tUePmX_S5B8ieZkkM7WUU2CnO8SmShwmAeWK9x2rTFo=' # <-- decryption key
            # to be requested from the library maintainers if you want to use default scenarios included in `premise`
    )
# Out:
# +------------------------------------------------------------------+
# | Warning                                                          |
# +------------------------------------------------------------------+
# | Because some of the scenarios can yield LCI databases            |
# | containing net negative emission technologies (NET),             |
# | it is advised to account for biogenic CO2 flows when calculating |
# | Global Warming potential indicators.                             |
# | `premise_gwp` provides characterization factors for such flows.  |
# | It also provides factors for hydrogen emissions to air.          |
# |                                                                  |
# | Within your bw2 project:                                         |
# | from premise_gwp import add_premise_gwp                          |
# | add_premise_gwp()                                                |
# +------------------------------------------------------------------+
#
# ...

# %% [markdown]
# If you do not want to integrate the IAM projections in the database, but only wish to have the additional inventories, you can stop here and export the database back to Brightway or other destinations, by using the `write_db_to` methods, like so:

# %%
ndb.update_all()
# Out:
# ////////////////////////// TWO-WHEELERS ////////////////////////////
# Extracted 39 worksheets in 4.27 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Done!
# Extracted 39 worksheets in 3.38 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Done!
# Extracted 39 worksheets in 2.71 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Done!
# Extracted 39 worksheets in 3.78 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Done!
#
# ///////////////////////// PASSENGER CARS ///////////////////////////
# Extracted 1 worksheets in 13.77 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
# Extracted 1 worksheets in 15.63 seconds
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Create fleet average vehicles...
# Done!
# ...

# %% [markdown]
# # Export

# %% [markdown]
# ### As a Superstructure database
# A superstructure database is a database that can accomodate several scenarios, as described [here](https://github.com/dgdekoning/brightway-superstructure), to be then used in [Activity-Browser](https://github.com/LCA-ActivityBrowser/activity-browser).
# This function will export the superstructure database as well as produce a "scenario difference file". Hence, even though you create multiple scenarios, **you only need to write to disk one database**.

# %%
ndb.write_superstructure_db_to_brightway(name="Superstructure database")
# Out:
# Prepare database 1.
# One or multiple duplicates detected. Removing them...
# Prepare database 2.
# One or multiple duplicates detected. Removing them...
# Prepare database 3.
# One or multiple duplicates detected. Removing them...
# Prepare database 4.
# One or multiple duplicates detected. Removing them...
# Looping through scenarios to detect changes...
# Export a scenario difference file.
# Dropped 14767 duplicates.
# Scenario difference file exported to C:\Users\avdoever\Anaconda3\envs\premise_v2\Lib\site-packages\premise\data\export\scenario diff files\scenario_diff_Superstructure database.xlsx!
# Adding exchanges to 12544 activities.
# Adding 27448 extra activities to the original database...
# Done!
# One or multiple duplicates detected. Removing them...
# 35666 datasets
# 943050 exchanges
# 0 unlinked exchanges
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:04:30
# ...
